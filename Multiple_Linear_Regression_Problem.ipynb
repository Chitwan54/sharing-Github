# %% [markdown]
# # House Sales in King County USA

# %%
# Import Modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset

df = pd.read_csv(r"C:\Users\manch\OneDrive\Desktop\Datasets\kc_house_data.csv")

# %%
df.head(n=10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
# Display all the colums
pd.set_option("display.max_columns", None)

# %%
df.head(n=10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# # Handling Missing Values

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# # Data Visualisation

# %%
# I am confused with this 'waterfront' column let's plot it
plt.scatter(df['waterfront'], df['price'])

'''From the scatter plot it is pretty clear that the column wavefront is a boolean variable, so change the type'''

df['waterfront'] = df['waterfront'].astype("bool")
df['bathrooms'] = df['bathrooms'].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int32
#  2   bathrooms      21613 non-null  int32
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  bool
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
# ...

# %%
# Similarly for view
plt.bar(df['view'], df['price'])
# Out:
# <BarContainer object of 21613 artists>

# %%
plt.bar(df['waterfront'], df['price'])
# Out:
# <BarContainer object of 21613 artists>

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      1.749734   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.734873    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.000000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.000000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.000000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors          view     condition         grade    sqft_above  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.234303      3.409430      7.656873   1788.390691
# ...

# %%
df.drop(['id','date'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3          1         1180      5650     1.0       False
# 1  538000.0         3          2         2570      7242     2.0       False
# 2  180000.0         2          1          770     10000     1.0       False
# 3  604000.0         4          3         1960      5000     1.0       False
# 4  510000.0         3          2         1680      8080     1.0       False
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df['yr_renovated'].describe()
# Out:
# count    21613.000000
# mean        84.402258
# std        401.679240
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2015.000000
# Name: yr_renovated, dtype: float64

# %%
# Visualise the columns
# 1. Scatter Plots

scatter_columns = ['sqft_lot','sqft_above','sqft_living', 'sqft_basement', 'sqft_living15', 'sqft_lot15' , 'lat', 'long','yr_built']
plt.figure(figsize = (20,20))
for i in range(len(scatter_columns)):
    plt.subplot(4,3,i+1)
    plt.scatter(df[scatter_columns[i]],df['price'])
    plt.xlabel(scatter_columns[i])
    plt.ylabel('Price')

# %%
#2. Bar Graphs

bar_plots = ["floors", "view", "floors", "condition", "grade", 'bedrooms', 'bathrooms']
plt.figure(figsize = (20, 20))
for i in range(len(bar_plots)):
    plt.subplot(6,6,i+1)
    plt.bar(df[bar_plots[i]], df['price'])
    plt.xlabel(bar_plots[i])
    plt.ylabel('Price')

# %%
# Drop lat, lang, yr_renovated, yr_built, zipcode
X = df.drop(['price', 'lat', 'long', 'yr_built', 'yr_renovated', 'zipcode', 'waterfront'], axis = 1)

# %%
y = df['price']

# %% [markdown]
# # Normalization

# %%
df.head(n=10)
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   221900.0         3          1         1180      5650     1.0       False
# 1   538000.0         3          2         2570      7242     2.0       False
# 2   180000.0         2          1          770     10000     1.0       False
# 3   604000.0         4          3         1960      5000     1.0       False
# 4   510000.0         3          2         1680      8080     1.0       False
# 5  1225000.0         4          4         5420    101930     1.0       False
# 6   257500.0         3          2         1715      6819     2.0       False
# 7   291850.0         3          1         1060      9711     1.0       False
# 8   229500.0         3          1         1780      7470     1.0       False
# 9   323000.0         3          2         1890      6560     2.0       False
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
X.head(n=10)
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  condition  grade  \
# 0         3          1         1180      5650     1.0     0          3      7
# 1         3          2         2570      7242     2.0     0          3      7
# 2         2          1          770     10000     1.0     0          3      6
# 3         4          3         1960      5000     1.0     0          5      7
# 4         3          2         1680      8080     1.0     0          3      8
# 5         4          4         5420    101930     1.0     0          3     11
# 6         3          2         1715      6819     2.0     0          3      7
# 7         3          1         1060      9711     1.0     0          3      7
# 8         3          1         1780      7470     1.0     0          3      7
# 9         3          2         1890      6560     2.0     0          3      7
#
#    sqft_above  sqft_basement  sqft_living15  sqft_lot15
# ...

# %%
X = X.values

# %%
y = y.values

# %%
print(X.shape)
print(y.shape)
# Out:
# (21613, 12)
# (21613,)

# %%
# Convert int into float

'''Some Numpy functions require only float values, so we will have to convert int into float.'''
X.astype('float')
# Out:
# array([[3.000e+00, 1.000e+00, 1.180e+03, ..., 0.000e+00, 1.340e+03,
#         5.650e+03],
#        [3.000e+00, 2.000e+00, 2.570e+03, ..., 4.000e+02, 1.690e+03,
#         7.639e+03],
#        [2.000e+00, 1.000e+00, 7.700e+02, ..., 0.000e+00, 2.720e+03,
#         8.062e+03],
#        ...,
#        [2.000e+00, 0.000e+00, 1.020e+03, ..., 0.000e+00, 1.020e+03,
#         2.007e+03],
#        [3.000e+00, 2.000e+00, 1.600e+03, ..., 0.000e+00, 1.410e+03,
#         1.287e+03],
#        [2.000e+00, 0.000e+00, 1.020e+03, ..., 0.000e+00, 1.020e+03,
#         1.357e+03]])

# %%
X.dtype
# Out:
# dtype('float64')

# %%
# Normalisation
u = np.mean(X,axis = 0)
std = np.std(X,axis = 0)

# %%
# Normalised data
X = (X-u)/std

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (15129, 12)
# (6484, 12)

# %% [markdown]
# ## Linear Regression

# %%
# Create a numpy array of 1's for stacking X0
ones = np.ones((X.shape[0],1))

# Stack it with X
X = np.hstack((ones, X))
X.shape
# Out:
# (21613, 13)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (15129, 13)
# (6484, 13)

# %%
# Generate Hypothesis
def hypothesis(X, theta):
    
    return np.dot(X,theta)

# error function
def total_error(X,y, theta):
    
    m,n = X.shape
    error = 0.0
    
    for i in range(m):
        
        # Call the hypothesis function
        y_ = hypothesis(X[i], theta)
        
        # Calcuate the error function
        error += (y - y_)**2
        
    return error/m

# Gradient
def gradient(X, y, theta):
    
    m,n = X.shape
    grad = np.zeros((n,))
    
    for j in range(n):
        for i in range(m):
            
            # Call the hypothesis
            y_ = hypothesis(X[i], theta)
            
            # Gradient
            grad[j] += (y[i] - y_)*X[i][j]
            
    return grad/m

# Gradient Descent
def gradient_descent(X, y, learning_rate = 0.01, max_iter = 75):
    
    m,n = X.shape
    
    # Randomly initialize thetas
    theta = np.zeros((n,))
    
    # Create an error list
    error_list = []
    
    # Perform the update rule
    for i in range(max_iter):
        
        # Call the gradient
        grad = gradient(X, y, theta)
        
        # Call the error function
        e = total_error(X, y, theta)
        error_list.append(e)
        
        # Perform the update rule
        for j in range(n):
            
            theta[j] = theta[j] - learning_rate* grad[j]
    
    return theta, error_list

# %%
(theta, error_list) = gradient_descent(X_train, y_train)

# %%
theta
# Out:
# array([ -586361.70497559,  -861199.25406965, -1174960.205913  ,
#        -1440064.012102  ,  -307944.26613517,  -719959.93240652,
#         -546792.52561413,   161388.9522694 , -1309545.04215388,
#        -1344245.41512086,  -473267.04597053, -1247443.83646083,
#         -329710.13862024])

# %%
# Plot the error list
plt.plot(error_list)
plt.title("Error v/s Iterations")
plt.show()

# %% [markdown]
# ## Make Predictions

# %%
# Make Predictions on the training data set
def predictions(X,Y, theta):
    y_ = []
    m,n = X.shape
    for i in range(m):
        predictions = hypothesis(X[i], theta)
        y_.append(predictions)
    y_ = np.array(y_)
    return y_

# Calculate the R2 score
def R2_score(y, y_predictions):
    
    num = np.sum((y - y_predictions)**2)
    den = np.sum((y-y.mean())**2)
    
    r2_score = 1 - (num/den)
    return r2_score*100

# %%
y_train_predictions = predictions(X_train, y_train, theta)

# %%
R2_score(y_train, y_train_predictions)
# Out:
# -39375.73067441284

# %%
y_test_predictions = predictions(X_test, y_test, theta)

# %%
R2_score(y_test, y_test_predictions)
# Out:
# -41220.23368713901
